# %%
import pandas as pd
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv
from urllib.parse import quote_plus
import psycopg2

# %%
# Load environment variables from .env
load_dotenv()
# Out:
# True

# %%
# Fetch database credentials from .env
DB_NAME = os.getenv("DB_NAME")
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")

# Encode the password to handle special characters
password_encoded = quote_plus(DB_PASSWORD)

# Use only this connection string (DO NOT create another one)
connection_url = f'postgresql://{DB_USER}:{password_encoded}@{DB_HOST}:{DB_PORT}/{DB_NAME}'

# Use this engine throughout the script
engine = create_engine(connection_url)

# %%
# Establish a connection using psycopg2
conn = psycopg2.connect(
    dbname=DB_NAME,
    user=DB_USER,
    password=DB_PASSWORD,
    host=DB_HOST,
    port=DB_PORT
)
cursor = conn.cursor()

print("Connection to PostgreSQL successful!")
# Out:
# Connection to PostgreSQL successful!

# %%
# Testing the connection by fetching table names
query = "SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"
tables = pd.read_sql(query, engine)
print(tables)
# Out:
#     table_name
# 0  credit_data

# %%
# Ensuring all columns are correctly stored in PostgreSQL
query = """
SELECT column_name, data_type
FROM information_schema.columns
WHERE table_name = 'credit_data';
""" 
columns_info = pd.read_sql(query, engine)
columns_info
# Out:
#                    column_name         data_type
# 0                           id            bigint
# 1                    limit_bal            bigint
# 2                          sex            bigint
# 3                    education            bigint
# 4                     marriage            bigint
# 5                          age            bigint
# 6                        pay_0            bigint
# 7                        pay_2            bigint
# 8                        pay_3            bigint
# 9                        pay_4            bigint
# 10                       pay_5            bigint
# 11                       pay_6            bigint
# 12                   bill_amt1            bigint
# 13                   bill_amt2            bigint
# 14                   bill_amt3            bigint
# 15                   bill_amt4            bigint
# 16                   bill_amt5            bigint
# 17                   bill_amt6            bigint
# 18                    pay_amt1  double precision
# 19                    pay_amt2  double precision
# 20                    pay_amt3  double precision
# 21                    pay_amt4  double precision
# 22                    pay_amt5  double precision
# 23                    pay_amt6  double precision
# 24  default_payment_next_month            bigint
# 25           high_credit_limit            bigint
# 26       credit_limit_category              text
# 27             limit_bal_group              text
# 28               pay_amt_group              text
# 29              pay_amt1_group              text
# 30              pay_amt2_group              text
# 31              pay_amt3_group              text
# 32              pay_amt4_group              text
# 33              pay_amt5_group              text
# 34              pay_amt6_group              text

# %%
# Checking all the dataset fully loaded
query = """
SELECT COUNT(*) FROM credit_data;
"""
total_records = pd.read_sql(query, engine)
total_records
# Out:
#    count
# 0  29999

# %%
# Checking for any missing values

# Get column names dynamically from PostgreSQL
query_columns = """
SELECT column_name 
FROM information_schema.columns 
WHERE table_name = 'credit_data';
"""
columns = pd.read_sql(query_columns, engine)['column_name'].tolist()

# Generate SQL query dynamically
query_missing = "SELECT " + ", ".join(
    [f"SUM(CASE WHEN {col} IS NULL THEN 1 ELSE 0 END) AS {col}_missing" for col in columns]
) + " FROM credit_data;"

# Execute the query
missing_values = pd.read_sql(query_missing, engine)
missing_values
# Out:
#    id_missing  limit_bal_missing  sex_missing  education_missing  \
# 0           0                  0            0                  0
#
#    marriage_missing  age_missing  pay_0_missing  pay_2_missing  pay_3_missing  \
# 0                 0            0              0              0              0
#
#    pay_4_missing  ...  high_credit_limit_missing  \
# 0              0  ...                          0
#
#    credit_limit_category_missing  limit_bal_group_missing  \
# 0                              0                        0
#
#    pay_amt_group_missing  pay_amt1_group_missing  pay_amt2_group_missing  \
# 0                      0                       0                       0
#
#    pay_amt3_group_missing  pay_amt4_group_missing  pay_amt5_group_missing  \
# 0                       0                       0                       0
#
#    pay_amt6_group_missing
# 0                       0
#
# [1 rows x 35 columns]

# %%
# Checking for any duplicate values
query = """
SELECT COUNT(*) - COUNT(DISTINCT (id, limit_bal, sex, education, marriage, age, pay_0, pay_2, pay_3, pay_4, bill_amt1, bill_amt2, bill_amt3, bill_amt4, bill_amt5, bill_amt6, pay_amt1, pay_amt2, pay_amt3, pay_amt4, pay_amt5, pay_amt6, default_payment_next_month, high_credit_limit, credit_limit_category, limit_bal_group, pay_amt_group, pay_amt1_group, pay_amt2_group, pay_amt3_group, pay_amt4_group, pay_amt5_group, pay_amt6_group)) AS duplicate_count 
FROM credit_data;
"""
duplicates = pd.read_sql(query, engine)
duplicates
# Out:
#    duplicate_count
# 0                0

# %%
# Analyzing patterns and risk trends

query = """
SELECT
    MIN(limit_bal) AS min_limit_bal,
    MAX(limit_bal) AS max_limit_bal,
    AVG(limit_bal) AS avg_limit_bal,
    STDDEV(limit_bal) AS std_limit_bal,

    MIN(age) AS min_age,
    MAX(age) AS max_age,
    AVG(age) AS avg_age,
    STDDEV(age) AS std_age
FROM credit_data;
"""
overview_data = pd.read_sql(query, engine)
overview_data
# Out:
#    min_limit_bal  max_limit_bal  avg_limit_bal  std_limit_bal  min_age  \
# 0          10000        1000000  167475.238508  129740.283364       21
#
#    max_age    avg_age   std_age
# 0       75  35.484049  9.214633

# %%
# Analyzing distribution of credit limit
query = """
SELECT credit_limit_category, COUNT(*) AS count
FROM credit_data
GROUP BY credit_limit_category
ORDER BY credit_limit_category;
"""
credit_distribution = pd.read_sql(query, engine)
credit_distribution
# Out:
#     credit_limit_category  count
# 0       High Credit Limit   7643
# 1        Low Credit Limit   7676
# 2     Medium Credit Limit   7614
# 3  Very High Credit Limit   7066

# %%
# Analysing the late payments per category
query = """
SELECT
    pay_0, COUNT(*) AS count_pay_0,
    pay_2, COUNT(*) AS count_pay_2,
    pay_3, COUNT(*) AS count_pay_3,
    pay_4, COUNT(*) AS count_pay_4,
    pay_5, COUNT(*) AS count_pay_5,
    pay_6, COUNT(*) AS count_pay_6
FROM credit_data
GROUP BY pay_0, pay_2, pay_3, pay_4, pay_5, pay_6
ORDER BY pay_0 DESC, pay_2 DESC, pay_3 DESC, pay_4 DESC, pay_5 DESC, pay_6 DESC;
"""
late_payments = pd.read_sql(query, engine)
late_payments
# Out:
#       pay_0  count_pay_0  pay_2  count_pay_2  pay_3  count_pay_3  pay_4  \
# 0         8           19      7           19      6           19      5
# 1         7            9      6            9      5            9      4
# 2         6            1      5            1      4            1      4
# 3         6            2      5            2      4            2      3
# 4         6            8      5            8      4            8      3
# ...     ...          ...    ...          ...    ...          ...    ...
# 1101     -2            8     -2            8     -2            8     -2
# 1102     -2           28     -2           28     -2           28     -2
# 1103     -2           49     -2           49     -2           49     -2
# 1104     -2           88     -2           88     -2           88     -2
# 1105     -2         2109     -2         2109     -2         2109     -2
#
#       count_pay_4  pay_5  count_pay_5  pay_6  count_pay_6
# 0              19      4           19      3           19
# 1               9      3            9      2            9
# 2               1      3            1      2            1
# 3               2      2            2      2            2
# 4               8      2            8      0            8
# ...           ...    ...          ...    ...          ...
# 1101            8     -1            8      2            8
# 1102           28     -1           28      0           28
# 1103           49     -1           49     -1           49
# 1104           88     -2           88     -1           88
# 1105         2109     -2         2109     -2         2109
#
# [1106 rows x 12 columns]

# %% [markdown]
# Observations:
# - Negative values like -2, -1 shows the advance payment
# - Higher 'pay' values indicates delay in payment.

# %%
# Checking spending behavior 
query = """
SELECT
    AVG(bill_amt1) AS avg_bill_1, MAX(bill_amt1) AS max_bill_1, MIN(bill_amt1) AS min_bill_1, STDDEV(bill_amt1) AS std_bill_1,
    AVG(bill_amt2) AS avg_bill_2, MAX(bill_amt2) AS max_bill_2, MIN(bill_amt2) AS min_bill_2, STDDEV(bill_amt2) AS std_bill_2,
    AVG(bill_amt3) AS avg_bill_3, MAX(bill_amt3) AS max_bill_3, MIN(bill_amt3) AS min_bill_3, STDDEV(bill_amt3) AS std_bill_3,
    AVG(bill_amt4) AS avg_bill_4, MAX(bill_amt4) AS max_bill_4, MIN(bill_amt4) AS min_bill_4, STDDEV(bill_amt4) AS std_bill_4,
    AVG(bill_amt5) AS avg_bill_5, MAX(bill_amt5) AS max_bill_5, MIN(bill_amt5) AS min_bill_5, STDDEV(bill_amt5) AS std_bill_5,
    AVG(bill_amt6) AS avg_bill_6, MAX(bill_amt6) AS max_bill_6, MIN(bill_amt6) AS min_bill_6, STDDEV(bill_amt6) AS std_bill_6
FROM credit_data;
"""
spending_behavior = pd.read_sql(query, engine)
spending_behavior
# Out:
#      avg_bill_1  max_bill_1  min_bill_1    std_bill_1    avg_bill_2  \
# 0  49653.033968      298151           0  66400.993328  47451.615821
#
#    max_bill_2  min_bill_2    std_bill_2    avg_bill_3  max_bill_3  ...  \
# 0      276871           0  63307.142341  45245.855362      267366  ...
#
#    min_bill_4    std_bill_4    avg_bill_5  max_bill_5  min_bill_5  \
# 0           0  56622.941349  38674.999933      231693           0
#
#      std_bill_5    avg_bill_6  max_bill_6  min_bill_6    std_bill_6
# 0  53175.425231  37288.167172      224031           0  51950.179641
#
# [1 rows x 24 columns]

# %% [markdown]
# Observations:
# - avg_bill values is around 50K but the standard deviation is higher than the `avg_bill` this shows spending varies in wider range
# - max_bill is ~298K indicating some high spending customers

# %%
# Checking the correlation between default_payment_next_month and credit limit, late payments, and spending habits are related to defaults
query = """
SELECT
    pay_0, COUNT(*) FILTER (WHERE default_payment_next_month = 1) AS defaulters_count,
    pay_2, COUNT(*) FILTER (WHERE default_payment_next_month = 1) AS defaulters_count_2,
    pay_3, COUNT(*) FILTER (WHERE default_payment_next_month = 1) AS defaulters_count_3,
    pay_4, COUNT(*) FILTER (WHERE default_payment_next_month = 1) AS defaulters_count_4,
    pay_5, COUNT(*) FILTER (WHERE default_payment_next_month = 1) AS defaulters_count_5,
    pay_6, COUNT(*) FILTER (WHERE default_payment_next_month = 1) AS defaulters_count_6
FROM credit_data
GROUP BY pay_0, pay_2, pay_3, pay_4, pay_5, pay_6
ORDER BY defaulters_count DESC;
"""
correlation_analysis = pd.read_sql(query, engine)
correlation_analysis
# Out:
#       pay_0  defaulters_count  pay_2  defaulters_count_2  pay_3  \
# 0         0              1026      0                1026      0
# 1         2               411      2                 411      2
# 2         2               339      0                 339      0
# 3        -1               284     -1                 284     -1
# 4        -2               284     -2                 284     -2
# ...     ...               ...    ...                 ...    ...
# 1101      0                 0      0                   0     -1
# 1102      2                 0      2                   0      3
# 1103     -1                 0      0                   0      0
# 1104      1                 0      2                   0      2
# 1105     -2                 0     -1                   0     -1
#
#       defaulters_count_3  pay_4  defaulters_count_4  pay_5  \
# 0                   1026      0                1026      0
# 1                    411      2                 411      2
# 2                    339      0                 339      0
# 3                    284     -1                 284     -1
# 4                    284     -2                 284     -2
# ...                  ...    ...                 ...    ...
# 1101                   0      0                   0     -1
# 1102                   0      3                   0      2
# 1103                   0      2                   0      2
# 1104                   0      2                   0      3
# 1105                   0     -1                   0      0
#
#       defaulters_count_5  pay_6  defaulters_count_6
# 0                   1026      0                1026
# 1                    411      2                 411
# 2                    339      0                 339
# 3                    284     -1                 284
# 4                    284     -2                 284
# ...                  ...    ...                 ...
# 1101                   0      0                   0
# 1102                   0     -1                   0
# 1103                   0      0                   0
# 1104                   0      4                   0
# 1105                   0     -1                   0
#
# [1106 rows x 12 columns]

# %% [markdown]
# Observations:
# - When pay_ values increases the default rate seems high
# - Many defaulters had pay_0 = 0, customerswith pay_2 = 2 show high default count

# %%
# Churn Analysis

# Caculating overall churn rate
query = """
SELECT
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS total_defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS churn_rate
FROM credit_data;
"""
overall_churn_rate = pd.read_sql(query, engine)
overall_churn_rate
# Out:
#    total_customers  total_defaulters  churn_rate
# 0            29999              6636       22.12

# %% [markdown]
# Observations:
# - 22.12% of customers default on their payments

# %%
# Analysing churn rate by credit limit
query = """
SELECT
    limit_bal,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS total_defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS churn_rate
FROM credit_data
GROUP BY limit_bal
ORDER BY churn_rate DESC;
"""
credit_churn_rate = pd.read_sql(query, engine)
credit_churn_rate
# Out:
#     limit_bal  total_customers  total_defaulters  churn_rate
# 0      327680                1                 1      100.00
# 1      740000                2                 1       50.00
# 2       40000              230                92       40.00
# 3       10000              493               197       39.96
# 4       20000             1976               698       35.32
# ..        ...              ...               ...         ...
# 76     540000                6                 0        0.00
# 77      16000                2                 0        0.00
# 78     800000                2                 0        0.00
# 79     570000                8                 0        0.00
# 80    1000000                1                 0        0.00
#
# [81 rows x 4 columns]

# %% [markdown]
# observations:
# - customers with 40000 and 10000 limit have highest default rate of ~40%
# - some high-credit-limit customers (540000+) have a 0% churn rate

# %%
# Analyzing churn_rate by payment delays
query = """
SELECT 
    'pay_0' AS pay_category, pay_0 AS delay_level,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS total_defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS churn_rate
FROM credit_data 
GROUP BY pay_0 

UNION ALL

SELECT 
    'pay_2' AS pay_category, pay_2 AS delay_level,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS total_defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS churn_rate
FROM credit_data 
GROUP BY pay_2 

UNION ALL

SELECT 
    'pay_3' AS pay_category, pay_3 AS delay_level,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS total_defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS churn_rate
FROM credit_data 
GROUP BY pay_3 

UNION ALL

SELECT 
    'pay_4' AS pay_category, pay_4 AS delay_level,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS total_defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS churn_rate
FROM credit_data 
GROUP BY pay_4 

UNION ALL

SELECT 
    'pay_5' AS pay_category, pay_5 AS delay_level,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS total_defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS churn_rate
FROM credit_data 
GROUP BY pay_5 

UNION ALL

SELECT 
    'pay_6' AS pay_category, pay_6 AS delay_level,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS total_defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS churn_rate
FROM credit_data 
GROUP BY pay_6 
ORDER BY pay_category, delay_level DESC;
"""
churn_payment_delays = pd.read_sql(query, engine)
churn_payment_delays
# Out:
#    pay_category  delay_level  total_customers  total_defaulters  churn_rate
# 0         pay_0            8               19                11       57.89
# 1         pay_0            7                9                 7       77.78
# 2         pay_0            6               11                 6       54.55
# 3         pay_0            5               26                13       50.00
# 4         pay_0            4               76                52       68.42
# ..          ...          ...              ...               ...         ...
# 59        pay_6            3              184               118       64.13
# 60        pay_6            2             2766              1401       50.65
# 61        pay_6            0            16285              3069       18.85
# 62        pay_6           -1             5740               975       16.99
# 63        pay_6           -2             4895               981       20.04
#
# [64 rows x 5 columns]

# %% [markdown]
# Observations:
# - Customers with high payment delays like 6,7,8 have higher churn rate of 75% and above
# - Customers with 1-3 months payment delay have varing churn rates
# - Customers with no delays have churn rate below 20%

# %%
# Analyzing churn rate by spending behavior
query = """
SELECT
    CASE
        WHEN bill_amt1 + bill_amt2 + bill_amt3 + bill_amt4 + bill_amt5 + bill_amt6 < 50000 THEN 'Low Spender'
        WHEN bill_amt1 + bill_amt2 + bill_amt3 + bill_amt4 + bill_amt5 + bill_amt6 BETWEEN 50000 AND 200000 THEN 'Medium Spender'
        ELSE 'High Spender'
    END AS spending_category,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS total_defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS churn_rate
FROM credit_data
GROUP BY spending_category
ORDER BY churn_rate DESC;
"""
spending_churn_rate = pd.read_sql(query, engine)
spending_churn_rate
# Out:
#   spending_category  total_customers  total_defaulters  churn_rate
# 0    Medium Spender             8908              2053       23.05
# 1       Low Spender             9526              2163       22.71
# 2      High Spender            11565              2420       20.93

# %% [markdown]
# Observations:
# - Medium and Low spenders have higher churn rate of 23.05% and 22.71%
# - High spenders have 20.93%, may be they are more financially stable

# %% [markdown]
# Fraud Trend Analysis:
# - Unusual repayment behavior
# - Customers who pay very little despite high bills
# - Credit limit overuse signals

# %%
# Unusual repayment behavior: Checking customers who consistently pay very little compared to their bill amount

query = """
SELECT
    id,
    bill_amt1,
    pay_amt1,
    ROUND(CAST((pay_amt1 / NULLIF(bill_amt1, 0)) * 100 AS NUMERIC), 2) AS payment_ratio,
    CASE
        WHEN (pay_amt1 / NULLIF(bill_amt1, 0)) < 0.05 THEN 'Highly Unusual Behavior'
        WHEN (pay_amt1 / NULLIF(bill_amt1, 0)) < 0.10 THEN 'Unusual Behavior'
        ELSE 'Normal Behavior'
    END AS payment_behavior
FROM credit_data
WHERE bill_amt1 > 0
ORDER BY payment_ratio ASC;
"""
unusual_payment_behavior = pd.read_sql(query, engine)

import pandas as pd
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

print(unusual_payment_behavior)
# Out:
#           id  bill_amt1   pay_amt1  payment_ratio         payment_behavior
# 0      15543      65087      0.000           0.00  Highly Unusual Behavior
# 1      22813      41730      0.000           0.00  Highly Unusual Behavior
# 2      22872     160596      6.000           0.00  Highly Unusual Behavior
# 3       3790      50471      0.000           0.00  Highly Unusual Behavior
# 4       3791       1197      0.000           0.00  Highly Unusual Behavior
# 5      16347       6369      0.000           0.00  Highly Unusual Behavior
# 6       6568      14500      0.000           0.00  Highly Unusual Behavior
# 7      24035       7326      0.000           0.00  Highly Unusual Behavior
# 8      16342       1248      0.000           0.00  Highly Unusual Behavior
# 9      16340      15780      0.000           0.00  Highly Unusual Behavior
# 10     16338         51      0.000           0.00  Highly Unusual Behavior
# 11     15386        336      0.000           0.00  Highly Unusual Behavior
# 12      3804      21723      0.000           0.00  Highly Unusual Behavior
# 13     13046     131635      0.000           0.00  Highly Unusual Behavior
# 14      6557      16014      0.000           0.00  Highly Unusual Behavior
# 15     13869       4980      0.000           0.00  Highly Unusual Behavior
# 16      6556      24172      0.000           0.00  Highly Unusual Behavior
# 17     13050      51421      0.000           0.00  Highly Unusual Behavior
# 18     16331      23155      0.000           0.00  Highly Unusual Behavior
# 19      3812      70952      0.000           0.00  Highly Unusual Behavior
# 20     13052      76978      0.000           0.00  Highly Unusual Behavior
# 21      3815        249      0.000           0.00  Highly Unusual Behavior
# 22      3816         12      0.000           0.00  Highly Unusual Behavior
# 23      6551      52935      0.000           0.00  Highly Unusual Behavior
# 24     16325     110575      0.000           0.00  Highly Unusual Behavior
# 25     22460      15570      0.000           0.00  Highly Unusual Behavior
# 26     26944      14440      0.000           0.00  Highly Unusual Behavior
# 27     13060      51187      0.000           0.00  Highly Unusual Behavior
# 28      3823      84718      0.000           0.00  Highly Unusual Behavior
# 29     28153       2418      0.000           0.00  Highly Unusual Behavior
# 30      3825        652      0.000           0.00  Highly Unusual Behavior
# 31      3827       6901      0.000           0.00  Highly Unusual Behavior
# 32     13858       3413      0.000           0.00  Highly Unusual Behavior
# 33      6542        420      0.000           0.00  Highly Unusual Behavior
# 34      6541      61432      0.000           0.00  Highly Unusual Behavior
# 35     17249      18666      0.000           0.00  Highly Unusual Behavior
# 36      3833       3845      0.000           0.00  Highly Unusual Behavior
# 37     16306       7642      0.000           0.00  Highly Unusual Behavior
# 38      3835      31097      0.000           0.00  Highly Unusual Behavior
# 39     16305      31087      0.000           0.00  Highly Unusual Behavior
# 40      3837       4400      0.000           0.00  Highly Unusual Behavior
# 41     22463      21769      0.000           0.00  Highly Unusual Behavior
# 42     16291     189697      0.000           0.00  Highly Unusual Behavior
# 43     16290     102250      0.000           0.00  Highly Unusual Behavior
# 44     27755      50638      0.000           0.00  Highly Unusual Behavior
# 45     16288      23280      0.000           0.00  Highly Unusual Behavior
# 46     22470       9518      0.000           0.00  Highly Unusual Behavior
# 47     28141      16891      0.000           0.00  Highly Unusual Behavior
# 48     26950       3919      0.000           0.00  Highly Unusual Behavior
# 49     24026       1050      0.000           0.00  Highly Unusual Behavior
# 50     26952      50179      0.000           0.00  Highly Unusual Behavior
# 51      5915       5059      0.000           0.00  Highly Unusual Behavior
# 52      6533       2500      0.000           0.00  Highly Unusual Behavior
# 53      6532       3498      0.000           0.00  Highly Unusual Behavior
# 54      6528      42053      0.000           0.00  Highly Unusual Behavior
# 55      6527        632      0.000           0.00  Highly Unusual Behavior
# 56     16275       2905      0.000           0.00  Highly Unusual Behavior
# 57     28126      17188      0.000           0.00  Highly Unusual Behavior
# 58     24023      79977      0.000           0.00  Highly Unusual Behavior
# 59      5916        150      0.000           0.00  Highly Unusual Behavior
# 60     22473     117868      0.000           0.00  Highly Unusual Behavior
# 61      6520        120      0.000           0.00  Highly Unusual Behavior
# 62     13087      21353      0.000           0.00  Highly Unusual Behavior
# 63      6515     292907      0.000           0.00  Highly Unusual Behavior
# 64     22475       3213      0.000           0.00  Highly Unusual Behavior
# 65      6514        780      0.000           0.00  Highly Unusual Behavior
# 66     15395       1743      0.000           0.00  Highly Unusual Behavior
# 67      3870      23812      0.000           0.00  Highly Unusual Behavior
# 68     22480       2480      0.000           0.00  Highly Unusual Behavior
# 69     16261      35771      0.000           0.00  Highly Unusual Behavior
# 70      3874      32119      0.000           0.00  Highly Unusual Behavior
# 71     13852      27934      0.000           0.00  Highly Unusual Behavior
# 72      3876       1314      0.000           0.00  Highly Unusual Behavior
# 73      6512        780      0.000           0.00  Highly Unusual Behavior
# 74     24018       5814      0.000           0.00  Highly Unusual Behavior
# 75      3879       1050      0.000           0.00  Highly Unusual Behavior
# 76      6510       1050      0.000           0.00  Highly Unusual Behavior
# 77     28116     114614      0.000           0.00  Highly Unusual Behavior
# 78      6508       2360      0.000           0.00  Highly Unusual Behavior
# 79      6507       5893      0.000           0.00  Highly Unusual Behavior
# 80     13092       1139      0.000           0.00  Highly Unusual Behavior
# 81     13101       5601      0.000           0.00  Highly Unusual Behavior
# 82     24013      20569      0.000           0.00  Highly Unusual Behavior
# 83     27218       8090      0.000           0.00  Highly Unusual Behavior
# 84     16241      29504      0.000           0.00  Highly Unusual Behavior
# 85     22499       1242      0.000           0.00  Highly Unusual Behavior
# 86     28105      31507      0.000           0.00  Highly Unusual Behavior
# 87      3892      80250      0.000           0.00  Highly Unusual Behavior
# 88     16239        390      0.000           0.00  Highly Unusual Behavior
# 89     22501       3490      0.000           0.00  Highly Unusual Behavior
# 90      6490      59878      0.000           0.00  Highly Unusual Behavior
# 91     24005      32590      0.000           0.00  Highly Unusual Behavior
# 92     16229       7621      0.000           0.00  Highly Unusual Behavior
# 93     24004      21673      0.000           0.00  Highly Unusual Behavior
# 94     16228      32577      0.000           0.00  Highly Unusual Behavior
# 95     26979      74477      0.000           0.00  Highly Unusual Behavior
# 96      5924       6283      0.000           0.00  Highly Unusual Behavior
# 97     26981      41300      0.000           0.00  Highly Unusual Behavior
# 98     28100     182176      0.000           0.00  Highly Unusual Behavior
# 99     28097      27094      0.000           0.00  Highly Unusual Behavior
# 100     6475     234922      6.000           0.00  Highly Unusual Behavior
# 101    13140       4608      0.000           0.00  Highly Unusual Behavior
# 102    22506       2729      0.000           0.00  Highly Unusual Behavior
# 103    13145       2222      0.000           0.00  Highly Unusual Behavior
# 104    13154     156713      0.000           0.00  Highly Unusual Behavior
# 105    15400       5600      0.000           0.00  Highly Unusual Behavior
# 106    27760      51243      0.000           0.00  Highly Unusual Behavior
# 107    22861        739      0.000           0.00  Highly Unusual Behavior
# 108     5925     298151      0.000           0.00  Highly Unusual Behavior
# 109     4594       5431      0.000           0.00  Highly Unusual Behavior
# 110     3921       2630      0.000           0.00  Highly Unusual Behavior
# 111    26986       2500      0.000           0.00  Highly Unusual Behavior
# 112     6463        886      0.000           0.00  Highly Unusual Behavior
# 113    13159      51400      0.000           0.00  Highly Unusual Behavior
# 114    13164       3607      0.000           0.00  Highly Unusual Behavior
# 115     6458       5253      0.000           0.00  Highly Unusual Behavior
# 116    15406     132571      0.000           0.00  Highly Unusual Behavior
# 117    13848       2500      0.000           0.00  Highly Unusual Behavior
# 118     5928      12130      0.000           0.00  Highly Unusual Behavior
# 119     5929      22701      0.000           0.00  Highly Unusual Behavior
# 120    13178       2500      0.000           0.00  Highly Unusual Behavior
# 121    13179       2869      0.000           0.00  Highly Unusual Behavior
# 122    13185      18585      0.000           0.00  Highly Unusual Behavior
# 123     3937       1736      0.000           0.00  Highly Unusual Behavior
# 124    16191       7081      0.000           0.00  Highly Unusual Behavior
# 125     6440       4533      0.000           0.00  Highly Unusual Behavior
# 126    28084       1650      0.000           0.00  Highly Unusual Behavior
# 127    23982        546      0.000           0.00  Highly Unusual Behavior
# 128     3945        780      0.000           0.00  Highly Unusual Behavior
# 129     3947        329      0.000           0.00  Highly Unusual Behavior
# 130    13205      11052      0.000           0.00  Highly Unusual Behavior
# 131    28082       8678      0.000           0.00  Highly Unusual Behavior
# 132    16189      95564      0.000           0.00  Highly Unusual Behavior
# 133     6435         99      0.000           0.00  Highly Unusual Behavior
# 134    13211       5961      0.000           0.00  Highly Unusual Behavior
# 135    16178      30715      0.000           0.00  Highly Unusual Behavior
# 136     6431        780      0.000           0.00  Highly Unusual Behavior
# 137    22524       2560      0.000           0.00  Highly Unusual Behavior
# 138    22530      66635      0.000           0.00  Highly Unusual Behavior
# 139     3960        780      0.000           0.00  Highly Unusual Behavior
# 140     6429     138910      0.000           0.00  Highly Unusual Behavior
# 141    22853      16560      0.000           0.00  Highly Unusual Behavior
# 142     3964      18168      0.000           0.00  Highly Unusual Behavior
# 143    27006      23633      0.000           0.00  Highly Unusual Behavior
# 144     6427     100016      0.000           0.00  Highly Unusual Behavior
# 145    13232       2400      0.000           0.00  Highly Unusual Behavior
# 146    23961      12589      0.000           0.00  Highly Unusual Behavior
# 147    16142      69830      0.000           0.00  Highly Unusual Behavior
# 148    23959       5784      0.000           0.00  Highly Unusual Behavior
# 149    22545        657      0.000           0.00  Highly Unusual Behavior
# 150    16137     194640      0.000           0.00  Highly Unusual Behavior
# 151     6417     110109      0.000           0.00  Highly Unusual Behavior
# 152    13244       9864      0.000           0.00  Highly Unusual Behavior
# 153    22550       3544      0.000           0.00  Highly Unusual Behavior
# 154    16126      16944      0.000           0.00  Highly Unusual Behavior
# 155    16124      71900      0.000           0.00  Highly Unusual Behavior
# 156    22551      34440      0.000           0.00  Highly Unusual Behavior
# 157    16122      17836      0.000           0.00  Highly Unusual Behavior
# 158    28057      11776      0.000           0.00  Highly Unusual Behavior
# 159     5931      27226      0.000           0.00  Highly Unusual Behavior
# 160    22552       3755      0.000           0.00  Highly Unusual Behavior
# 161    28055       2400      0.000           0.00  Highly Unusual Behavior
# 162    13840        220      0.000           0.00  Highly Unusual Behavior
# 163     3993      17710      0.000           0.00  Highly Unusual Behavior
# 164     4583      31176      0.000           0.00  Highly Unusual Behavior
# 165     3995       9873      0.000           0.00  Highly Unusual Behavior
# 166    28049       4184      0.000           0.00  Highly Unusual Behavior
# 167    28048       4994      0.000           0.00  Highly Unusual Behavior
# 168    13254      14246      0.000           0.00  Highly Unusual Behavior
# 169     4002       1778      0.000           0.00  Highly Unusual Behavior
# 170    20676      11358      0.000           0.00  Highly Unusual Behavior
# 171    27014        780      0.000           0.00  Highly Unusual Behavior
# 172    23714        157      0.000           0.00  Highly Unusual Behavior
# 173     6394      42063      0.000           0.00  Highly Unusual Behavior
# 174     4007       1050      0.000           0.00  Highly Unusual Behavior
# 175    13837       5155      0.000           0.00  Highly Unusual Behavior
# 176     4580     177088      0.000           0.00  Highly Unusual Behavior
# 177    13259     181339      0.000           0.00  Highly Unusual Behavior
# 178     4014      19529      0.000           0.00  Highly Unusual Behavior
# 179    13262      69183      0.000           0.00  Highly Unusual Behavior
# 180     4016      90822      0.000           0.00  Highly Unusual Behavior
# 181     4579        652      0.000           0.00  Highly Unusual Behavior
# 182    23950      14665      0.000           0.00  Highly Unusual Behavior
# 183     4020      27896      0.000           0.00  Highly Unusual Behavior
# 184    23325       1870      0.000           0.00  Highly Unusual Behavior
# 185     6383      82891      0.000           0.00  Highly Unusual Behavior
# 186    16104       3305      0.000           0.00  Highly Unusual Behavior
# 187    27765       6272      0.000           0.00  Highly Unusual Behavior
# 188    13830      30739      0.000           0.00  Highly Unusual Behavior
# 189    16092      97229      0.000           0.00  Highly Unusual Behavior
# 190    23941      15000      0.000           0.00  Highly Unusual Behavior
# 191    23940      47568      0.000           0.00  Highly Unusual Behavior
# 192    16088       1249      0.000           0.00  Highly Unusual Behavior
# 193     6371     113722      0.000           0.00  Highly Unusual Behavior
# 194    15428       2500      0.000           0.00  Highly Unusual Behavior
# 195    13287       2500      0.000           0.00  Highly Unusual Behavior
# 196    13829      47906      0.000           0.00  Highly Unusual Behavior
# 197     4040     122283      0.000           0.00  Highly Unusual Behavior
# 198    13288      75505      0.000           0.00  Highly Unusual Behavior
# 199    28032      42488      0.000           0.00  Highly Unusual Behavior
# 200     4044       2734      0.000           0.00  Highly Unusual Behavior
# 201    16069       3089      0.000           0.00  Highly Unusual Behavior
# 202    16067      52714      0.000           0.00  Highly Unusual Behavior
# 203    16065       2489      0.000           0.00  Highly Unusual Behavior
# 204     6363      19844      0.000           0.00  Highly Unusual Behavior
# 205    23935      18292      0.000           0.00  Highly Unusual Behavior
# 206    13299      92400      0.000           0.00  Highly Unusual Behavior
# 207    13301      51345      0.000           0.00  Highly Unusual Behavior
# 208     6358        465      0.000           0.00  Highly Unusual Behavior
# 209    22573       4498      0.000           0.00  Highly Unusual Behavior
# 210    15440     156387      0.000           0.00  Highly Unusual Behavior
# 211    27212      31649      0.000           0.00  Highly Unusual Behavior
# 212     4062       2115      0.000           0.00  Highly Unusual Behavior
# 213    13308      46745      0.000           0.00  Highly Unusual Behavior
# 214     6348      82274      0.000           0.00  Highly Unusual Behavior
# 215    27028        150      0.000           0.00  Highly Unusual Behavior
# 216    22846       2615      0.000           0.00  Highly Unusual Behavior
# 217    16044         65      0.000           0.00  Highly Unusual Behavior
# 218    27030       2988      0.000           0.00  Highly Unusual Behavior
# 219    16040       5000      0.000           0.00  Highly Unusual Behavior
# 220    16039       2120      0.000           0.00  Highly Unusual Behavior
# 221    13314      28189      0.000           0.00  Highly Unusual Behavior
# 222     6338      20155      0.000           0.00  Highly Unusual Behavior
# 223     6337      34785      0.000           0.00  Highly Unusual Behavior
# 224    16032      17044      0.000           0.00  Highly Unusual Behavior
# 225     4077       9549      0.000           0.00  Highly Unusual Behavior
# 226    16028      25562      0.000           0.00  Highly Unusual Behavior
# 227    28017        444      0.000           0.00  Highly Unusual Behavior
# 228    16026      10211      0.000           0.00  Highly Unusual Behavior
# 229    13317      65520      0.000           0.00  Highly Unusual Behavior
# 230    28016       4577      0.000           0.00  Highly Unusual Behavior
# 231    22577       2435      0.000           0.00  Highly Unusual Behavior
# 232     4085      29846      0.000           0.00  Highly Unusual Behavior
# 233    16017     151790      0.000           0.00  Highly Unusual Behavior
# 234    27774       3177      0.000           0.00  Highly Unusual Behavior
# 235     5952       5731      0.000           0.00  Highly Unusual Behavior
# 236    13339      20852      0.000           0.00  Highly Unusual Behavior
# 237    13341     298151      0.000           0.00  Highly Unusual Behavior
# 238    23922       4332      0.000           0.00  Highly Unusual Behavior
# 239     6321      26551      0.000           0.00  Highly Unusual Behavior
# 240    16001       2400      0.000           0.00  Highly Unusual Behavior
# 241    13349        750      0.000           0.00  Highly Unusual Behavior
# 242     5953      11200      0.000           0.00  Highly Unusual Behavior
# 243    22843       6783      0.000           0.00  Highly Unusual Behavior
# 244    15999        538      0.000           0.00  Highly Unusual Behavior
# 245     6317       2580      0.000           0.00  Highly Unusual Behavior
# 246    28010       3470      0.000           0.00  Highly Unusual Behavior
# 247    28005      20128      0.000           0.00  Highly Unusual Behavior
# 248    23919      17456      0.000           0.00  Highly Unusual Behavior
# 249    28001      27371      0.000           0.00  Highly Unusual Behavior
# 250     6313     263943      0.000           0.00  Highly Unusual Behavior
# 251     4110        489      0.000           0.00  Highly Unusual Behavior
# 252    15993      49644      0.000           0.00  Highly Unusual Behavior
# 253    23723      25775      0.000           0.00  Highly Unusual Behavior
# 254    15460       2006      0.000           0.00  Highly Unusual Behavior
# 255    23910        495      0.000           0.00  Highly Unusual Behavior
# 256     5960      34069      0.000           0.00  Highly Unusual Behavior
# 257     4555      23037      0.000           0.00  Highly Unusual Behavior
# 258    23726       3857      0.000           0.00  Highly Unusual Behavior
# 259    15984      13815      0.000           0.00  Highly Unusual Behavior
# 260    15981      28361      0.000           0.00  Highly Unusual Behavior
# 261     5963       1080      0.000           0.00  Highly Unusual Behavior
# 262    13389       5577      0.000           0.00  Highly Unusual Behavior
# 263     4124      73900      0.000           0.00  Highly Unusual Behavior
# 264     4125      44193      0.000           0.00  Highly Unusual Behavior
# 265    15977      18704      0.000           0.00  Highly Unusual Behavior
# 266    15976      10722      0.000           0.00  Highly Unusual Behavior
# 267     4129      12091      0.000           0.00  Highly Unusual Behavior
# 268    27980        160      0.000           0.00  Highly Unusual Behavior
# 269    15974      49487      0.000           0.00  Highly Unusual Behavior
# 270    27057      19450      0.000           0.00  Highly Unusual Behavior
# 271    23905      14542      0.000           0.00  Highly Unusual Behavior
# 272     4136      14190      0.000           0.00  Highly Unusual Behavior
# 273    22594       3286      0.000           0.00  Highly Unusual Behavior
# 274     6289       4482      0.000           0.00  Highly Unusual Behavior
# 275     5964      17325      0.000           0.00  Highly Unusual Behavior
# 276     6284      38675      0.000           0.00  Highly Unusual Behavior
# 277     6282      25899      0.000           0.00  Highly Unusual Behavior
# 278    22599       1000      0.000           0.00  Highly Unusual Behavior
# 279     6281        682      0.000           0.00  Highly Unusual Behavior
# 280    15951      50701      0.000           0.00  Highly Unusual Behavior
# 281     4146      43244      0.000           0.00  Highly Unusual Behavior
# 282    23727       2064      0.000           0.00  Highly Unusual Behavior
# 283    15948       2400      0.000           0.00  Highly Unusual Behavior
# 284     4150      15722      0.000           0.00  Highly Unusual Behavior
# 285    13407       2400      0.000           0.00  Highly Unusual Behavior
# 286    15474      12768      0.000           0.00  Highly Unusual Behavior
# 287    15942     108087      0.000           0.00  Highly Unusual Behavior
# 288    15940      27807      0.000           0.00  Highly Unusual Behavior
# 289     4547     184761      0.000           0.00  Highly Unusual Behavior
# 290     4156     204441      0.000           0.00  Highly Unusual Behavior
# 291    15936      28766      0.000           0.00  Highly Unusual Behavior
# 292     6272       2400      0.000           0.00  Highly Unusual Behavior
# 293     6269      87376      0.000           0.00  Highly Unusual Behavior
# 294    15923      82074      0.000           0.00  Highly Unusual Behavior
# 295     4162       2667      0.000           0.00  Highly Unusual Behavior
# 296    27963      73167      0.000           0.00  Highly Unusual Behavior
# 297     4164       2248      0.000           0.00  Highly Unusual Behavior
# 298    27958      29164      0.000           0.00  Highly Unusual Behavior
# 299    23901       2454      0.000           0.00  Highly Unusual Behavior
# 300    27072        450      0.000           0.00  Highly Unusual Behavior
# 301    22621      28447      0.000           0.00  Highly Unusual Behavior
# 302    15912      56555      0.000           0.00  Highly Unusual Behavior
# 303    13803      49220      0.000           0.00  Highly Unusual Behavior
# 304    23899      13294      0.000           0.00  Highly Unusual Behavior
# 305     4174     205150      0.000           0.00  Highly Unusual Behavior
# 306    13418      14949      0.000           0.00  Highly Unusual Behavior
# 307    23892      19901      0.000           0.00  Highly Unusual Behavior
# 308    15899      96343      0.000           0.00  Highly Unusual Behavior
# 309    15898      18354      0.000           0.00  Highly Unusual Behavior
# 310    13801       1000      0.000           0.00  Highly Unusual Behavior
# 311    27944        276      0.000           0.00  Highly Unusual Behavior
# 312     4185      23589      0.000           0.00  Highly Unusual Behavior
# 313    15891      29188      0.000           0.00  Highly Unusual Behavior
# 314    23890       1200      0.000           0.00  Highly Unusual Behavior
# 315    22629      21001      0.000           0.00  Highly Unusual Behavior
# 316    15886      10243      0.000           0.00  Highly Unusual Behavior
# 317     4194       8352      0.000           0.00  Highly Unusual Behavior
# 318    13449        780      0.000           0.00  Highly Unusual Behavior
# 319     4197      48006      0.000           0.00  Highly Unusual Behavior
# 320    27938      11238      0.000           0.00  Highly Unusual Behavior
# 321    15480      33597      0.000           0.00  Highly Unusual Behavior
# 322    15876      74001      0.000           0.00  Highly Unusual Behavior
# 323    27789       3302      0.000           0.00  Highly Unusual Behavior
# 324    13470        456      0.000           0.00  Highly Unusual Behavior
# 325     4205        373      0.000           0.00  Highly Unusual Behavior
# 326     6237       4377      0.000           0.00  Highly Unusual Behavior
# 327     4207       2522      0.000           0.00  Highly Unusual Behavior
# 328    15481      94257      0.000           0.00  Highly Unusual Behavior
# 329    13473       1094      0.000           0.00  Highly Unusual Behavior
# 330    23870     124652      6.000           0.00  Highly Unusual Behavior
# 331    15484       2900      0.000           0.00  Highly Unusual Behavior
# 332     4213      32945      0.000           0.00  Highly Unusual Behavior
# 333     6230        470      0.000           0.00  Highly Unusual Behavior
# 334    23866      82671      0.000           0.00  Highly Unusual Behavior
# 335    16901      38811      0.000           0.00  Highly Unusual Behavior
# 336    23865      15678      0.000           0.00  Highly Unusual Behavior
# 337    15851      51943      0.000           0.00  Highly Unusual Behavior
# 338    27791      47210      0.000           0.00  Highly Unusual Behavior
# 339    13486      31400      0.000           0.00  Highly Unusual Behavior
# 340    13799       3805      0.000           0.00  Highly Unusual Behavior
# 341     4225       2206      0.000           0.00  Highly Unusual Behavior
# 342    27926       2500      0.000           0.00  Highly Unusual Behavior
# 343    13487      15397      0.000           0.00  Highly Unusual Behavior
# 344    27923      24307      0.000           0.00  Highly Unusual Behavior
# 345    27086       2178      0.000           0.00  Highly Unusual Behavior
# 346    27921      19029      0.000           0.00  Highly Unusual Behavior
# 347    15835       2500      0.000           0.00  Highly Unusual Behavior
# 348    27920       2127      0.000           0.00  Highly Unusual Behavior
# 349     6218      10361      0.000           0.00  Highly Unusual Behavior
# 350    15832       4040      0.000           0.00  Highly Unusual Behavior
# 351     4240       1982      0.000           0.00  Highly Unusual Behavior
# 352    27916        300      0.000           0.00  Highly Unusual Behavior
# 353    27089       3201      0.000           0.00  Highly Unusual Behavior
# 354    15825       4073      0.000           0.00  Highly Unusual Behavior
# 355    22832      49624      0.000           0.00  Highly Unusual Behavior
# 356    13505      15609      0.000           0.00  Highly Unusual Behavior
# 357    16727      36243      0.000           0.00  Highly Unusual Behavior
# 358    15813       2750      0.000           0.00  Highly Unusual Behavior
# 359    15809     101080      0.000           0.00  Highly Unusual Behavior
# 360    27200        694      0.000           0.00  Highly Unusual Behavior
# 361     6203      44100      0.000           0.00  Highly Unusual Behavior
# 362    13515        664      0.000           0.00  Highly Unusual Behavior
# 363    13517      28763      0.000           0.00  Highly Unusual Behavior
# 364    15801      34443      0.000           0.00  Highly Unusual Behavior
# 365    23852       1148      0.000           0.00  Highly Unusual Behavior
# 366    27098       9238      0.000           0.00  Highly Unusual Behavior
# 367     4260      28731      0.000           0.00  Highly Unusual Behavior
# 368    15799      52180      0.000           0.00  Highly Unusual Behavior
# 369    22830         80      0.000           0.00  Highly Unusual Behavior
# 370     4263      32814      0.000           0.00  Highly Unusual Behavior
# 371     4264      10033      0.000           0.00  Highly Unusual Behavior
# 372    13527      63872      0.000           0.00  Highly Unusual Behavior
# 373    27104       2895      0.000           0.00  Highly Unusual Behavior
# 374     4268     205150      0.000           0.00  Highly Unusual Behavior
# 375    13530        140      0.000           0.00  Highly Unusual Behavior
# 376    23836       1865      0.000           0.00  Highly Unusual Behavior
# 377    22671       1017      0.000           0.00  Highly Unusual Behavior
# 378    15785      50668      0.000           0.00  Highly Unusual Behavior
# 379     6182      61089      0.000           0.00  Highly Unusual Behavior
# 380    23834       2684      0.000           0.00  Highly Unusual Behavior
# 381     6176      32233      0.000           0.00  Highly Unusual Behavior
# 382     6175     114430      0.000           0.00  Highly Unusual Behavior
# 383    13541      10000      0.000           0.00  Highly Unusual Behavior
# 384    13546      40712      0.000           0.00  Highly Unusual Behavior
# 385    13548     102650      0.000           0.00  Highly Unusual Behavior
# 386    27196       2500      0.000           0.00  Highly Unusual Behavior
# 387    15779      12764      0.000           0.00  Highly Unusual Behavior
# 388    27112      11300      0.000           0.00  Highly Unusual Behavior
# 389     4286      21635      0.000           0.00  Highly Unusual Behavior
# 390     6160     131096      0.000           0.00  Highly Unusual Behavior
# 391    13559        101      0.000           0.00  Highly Unusual Behavior
# 392    22688       1659      0.000           0.00  Highly Unusual Behavior
# 393    15773      31073      0.000           0.00  Highly Unusual Behavior
# 394    15500      51210      0.000           0.00  Highly Unusual Behavior
# 395     6153       1521      0.000           0.00  Highly Unusual Behavior
# 396     6149      34085      0.000           0.00  Highly Unusual Behavior
# 397     4295      19203      0.000           0.00  Highly Unusual Behavior
# 398     4296       9502      0.000           0.00  Highly Unusual Behavior
# 399    23824       1561      0.000           0.00  Highly Unusual Behavior
# 400    22697       3966      0.000           0.00  Highly Unusual Behavior
# 401     4299        850      0.000           0.00  Highly Unusual Behavior
# 402    15753        200      0.000           0.00  Highly Unusual Behavior
# 403     4301       2300      0.000           0.00  Highly Unusual Behavior
# 404    16595        619      0.000           0.00  Highly Unusual Behavior
# 405    15506      47479      0.000           0.00  Highly Unusual Behavior
# 406    15748      96491      0.000           0.00  Highly Unusual Behavior
# 407    15747      28108      0.000           0.00  Highly Unusual Behavior
# 408     4306       1490      0.000           0.00  Highly Unusual Behavior
# 409    15745      41867      0.000           0.00  Highly Unusual Behavior
# 410    15742     298151      0.000           0.00  Highly Unusual Behavior
# 411    13580      17010      0.000           0.00  Highly Unusual Behavior
# 412    27799      36175      0.000           0.00  Highly Unusual Behavior
# 413     4311       2457      0.000           0.00  Highly Unusual Behavior
# 414    15736      49310      0.000           0.00  Highly Unusual Behavior
# 415    15733      27369      0.000           0.00  Highly Unusual Behavior
# 416    13792      14380      0.000           0.00  Highly Unusual Behavior
# 417    22708       4035      0.000           0.00  Highly Unusual Behavior
# 418    13584        919      0.000           0.00  Highly Unusual Behavior
# 419    23812      60458      0.000           0.00  Highly Unusual Behavior
# 420    15721       5811      0.000           0.00  Highly Unusual Behavior
# 421     4521        146      0.000           0.00  Highly Unusual Behavior
# 422    27879       6266      0.000           0.00  Highly Unusual Behavior
# 423    27800      47068      0.000           0.00  Highly Unusual Behavior
# 424    13784       8541      0.000           0.00  Highly Unusual Behavior
# 425    15716      10648      0.000           0.00  Highly Unusual Behavior
# 426    27876      59580      0.000           0.00  Highly Unusual Behavior
# 427    15708       3633      0.000           0.00  Highly Unusual Behavior
# 428     4331      24386      0.000           0.00  Highly Unusual Behavior
# 429    15707      15315      0.000           0.00  Highly Unusual Behavior
# 430    27194      16352      0.000           0.00  Highly Unusual Behavior
# 431    22824       1023      0.000           0.00  Highly Unusual Behavior
# 432    15702        586      0.000           0.00  Highly Unusual Behavior
# 433     4337     298151      0.000           0.00  Highly Unusual Behavior
# 434     4339       3227      0.000           0.00  Highly Unusual Behavior
# 435    23803      26590      0.000           0.00  Highly Unusual Behavior
# 436    15700      21676      0.000           0.00  Highly Unusual Behavior
# 437    22716       2802      0.000           0.00  Highly Unusual Behavior
# 438     5989     285249      5.000           0.00  Highly Unusual Behavior
# 439    15693        350      0.000           0.00  Highly Unusual Behavior
# 440     6123      80762      0.000           0.00  Highly Unusual Behavior
# 441    23802       2155      0.000           0.00  Highly Unusual Behavior
# 442    13624       4205      0.000           0.00  Highly Unusual Behavior
# 443    13627       1672      0.000           0.00  Highly Unusual Behavior
# 444     4350      48580      0.000           0.00  Highly Unusual Behavior
# 445    15523       4949      0.000           0.00  Highly Unusual Behavior
# 446     6113      17155      0.000           0.00  Highly Unusual Behavior
# 447    22725        750      0.000           0.00  Highly Unusual Behavior
# 448    15680       2219      0.000           0.00  Highly Unusual Behavior
# 449    27802      11059      0.000           0.00  Highly Unusual Behavior
# 450    15675      17516      0.000           0.00  Highly Unusual Behavior
# 451    15674        760      0.000           0.00  Highly Unusual Behavior
# 452     5991     157122      0.000           0.00  Highly Unusual Behavior
# 453    27858      12508      0.000           0.00  Highly Unusual Behavior
# 454     4363        640      0.000           0.00  Highly Unusual Behavior
# 455     4364       1500      0.000           0.00  Highly Unusual Behavior
# 456     6112     117922      0.000           0.00  Highly Unusual Behavior
# 457    27193       2500      0.000           0.00  Highly Unusual Behavior
# 458     4367      62737      0.000           0.00  Highly Unusual Behavior
# 459    13636      24166      0.000           0.00  Highly Unusual Behavior
# 460    15671       1288      0.000           0.00  Highly Unusual Behavior
# 461    14129        296      0.000           0.00  Highly Unusual Behavior
# 462     4371       2017      0.000           0.00  Highly Unusual Behavior
# 463    27143       4908      0.000           0.00  Highly Unusual Behavior
# 464     4508      32755      0.000           0.00  Highly Unusual Behavior
# 465     4374       9999      0.000           0.00  Highly Unusual Behavior
# 466     4375      51300      0.000           0.00  Highly Unusual Behavior
# 467     4376      69311      0.000           0.00  Highly Unusual Behavior
# 468     4378      21509      0.000           0.00  Highly Unusual Behavior
# 469    15664       9193      0.000           0.00  Highly Unusual Behavior
# 470    13641      19393      0.000           0.00  Highly Unusual Behavior
# 471     5993      52180      0.000           0.00  Highly Unusual Behavior
# 472    23794      19127      0.000           0.00  Highly Unusual Behavior
# 473    15654       8050      0.000           0.00  Highly Unusual Behavior
# 474    13777      48421      0.000           0.00  Highly Unusual Behavior
# 475    15652      90880      0.000           0.00  Highly Unusual Behavior
# 476     4388     112662      0.000           0.00  Highly Unusual Behavior
# 477    29992       2500      0.000           0.00  Highly Unusual Behavior
# 478    13648        330      0.000           0.00  Highly Unusual Behavior
# 479     6094       3302      0.000           0.00  Highly Unusual Behavior
# 480    23789      51254      0.000           0.00  Highly Unusual Behavior
# 481     6090     112434      0.000           0.00  Highly Unusual Behavior
# 482    15643        994      0.000           0.00  Highly Unusual Behavior
# 483     4396       1413      0.000           0.00  Highly Unusual Behavior
# 484    23788      10440      0.000           0.00  Highly Unusual Behavior
# 485    23787      15399      0.000           0.00  Highly Unusual Behavior
# 486    13661      35997      0.000           0.00  Highly Unusual Behavior
# 487    27804       3000      0.000           0.00  Highly Unusual Behavior
# 488     6085       1050      0.000           0.00  Highly Unusual Behavior
# 489     6083      15910      0.000           0.00  Highly Unusual Behavior
# 490    13668      41300      0.000           0.00  Highly Unusual Behavior
# 491    27844      18025      0.000           0.00  Highly Unusual Behavior
# 492    13675      14320      0.000           0.00  Highly Unusual Behavior
# 493     4409     298151      0.000           0.00  Highly Unusual Behavior
# 494    20695     127370      0.000           0.00  Highly Unusual Behavior
# 495    27157      33666      0.000           0.00  Highly Unusual Behavior
# 496     6069      25244      0.000           0.00  Highly Unusual Behavior
# 497     4503      71570      0.000           0.00  Highly Unusual Behavior
# 498    27843       9600      0.000           0.00  Highly Unusual Behavior
# 499    15629       2330      0.000           0.00  Highly Unusual Behavior
# 500    22760       2650      0.000           0.00  Highly Unusual Behavior
# 501    13697      28859      0.000           0.00  Highly Unusual Behavior
# 502     4420        108      0.000           0.00  Highly Unusual Behavior
# 503    27161        300      0.000           0.00  Highly Unusual Behavior
# 504    23767        413      0.000           0.00  Highly Unusual Behavior
# 505    15627      10111      0.000           0.00  Highly Unusual Behavior
# 506     6056        150      0.000           0.00  Highly Unusual Behavior
# 507     6053      44306      0.000           0.00  Highly Unusual Behavior
# 508    27164       6744      0.000           0.00  Highly Unusual Behavior
# 509    13712       2500      0.000           0.00  Highly Unusual Behavior
# 510     6049      21092      0.000           0.00  Highly Unusual Behavior
# 511    13713      20753      0.000           0.00  Highly Unusual Behavior
# 512    13776      14103      0.000           0.00  Highly Unusual Behavior
# 513     4433      27669      0.000           0.00  Highly Unusual Behavior
# 514    27834      99290      0.000           0.00  Highly Unusual Behavior
# 515     4436        552      0.000           0.00  Highly Unusual Behavior
# 516     6045       4957      0.000           0.00  Highly Unusual Behavior
# 517     6044        780      0.000           0.00  Highly Unusual Behavior
# 518     6041       2400      0.000           0.00  Highly Unusual Behavior
# 519    15606      19667      0.000           0.00  Highly Unusual Behavior
# 520     4445     110072      0.000           0.00  Highly Unusual Behavior
# 521    15604      12509      0.000           0.00  Highly Unusual Behavior
# 522     4447       1243      0.000           0.00  Highly Unusual Behavior
# 523    23760        845      0.000           0.00  Highly Unusual Behavior
# 524     4449        780      0.000           0.00  Highly Unusual Behavior
# 525    13716        816      0.000           0.00  Highly Unusual Behavior
# 526    15598       9498      0.000           0.00  Highly Unusual Behavior
# 527    22819       2500      0.000           0.00  Highly Unusual Behavior
# 528    27826       4426      0.000           0.00  Highly Unusual Behavior
# 529    27166     238094      0.000           0.00  Highly Unusual Behavior
# 530    27167       7816      0.000           0.00  Highly Unusual Behavior
# 531     4456      47262      0.000           0.00  Highly Unusual Behavior
# 532    13717      66459      0.000           0.00  Highly Unusual Behavior
# 533    15536       1296      0.000           0.00  Highly Unusual Behavior
# 534    15581      29860      0.000           0.00  Highly Unusual Behavior
# 535    22787      13278      0.000           0.00  Highly Unusual Behavior
# 536    13731       1792      0.000           0.00  Highly Unusual Behavior
# 537     6029     120869      0.000           0.00  Highly Unusual Behavior
# 538    23752      24135      0.000           0.00  Highly Unusual Behavior
# 539     6026     274263      0.000           0.00  Highly Unusual Behavior
# 540     6025       1767      0.000           0.00  Highly Unusual Behavior
# 541    22791        223      0.000           0.00  Highly Unusual Behavior
# 542     6022       1117      0.000           0.00  Highly Unusual Behavior
# 543    15571      62177      0.000           0.00  Highly Unusual Behavior
# 544    13740       2400      0.000           0.00  Highly Unusual Behavior
# 545    15537      31476      0.000           0.00  Highly Unusual Behavior
# 546    13744       2497      0.000           0.00  Highly Unusual Behavior
# 547    27179      61650      0.000           0.00  Highly Unusual Behavior
# 548     4495       5674      0.000           0.00  Highly Unusual Behavior
# 549    13745      27044      0.000           0.00  Highly Unusual Behavior
# 550    13761       7174      0.000           0.00  Highly Unusual Behavior
# 551    22806       5239      0.000           0.00  Highly Unusual Behavior
# 552    13760        573      0.000           0.00  Highly Unusual Behavior
# 553     6013       1458      0.000           0.00  Highly Unusual Behavior
# 554     5372       7229      0.000           0.00  Highly Unusual Behavior
# 555    27456      25801      0.000           0.00  Highly Unusual Behavior
# 556     5367      20832      0.000           0.00  Highly Unusual Behavior
# 557    14510      28686      0.000           0.00  Highly Unusual Behavior
# 558    27459      66204      0.000           0.00  Highly Unusual Behavior
# 559    23324       4867      0.000           0.00  Highly Unusual Behavior
# 560     9583      15955      0.000           0.00  Highly Unusual Behavior
# 561     5346      51068      0.000           0.00  Highly Unusual Behavior
# 562     9543      12319      0.000           0.00  Highly Unusual Behavior
# 563    27469        898      0.000           0.00  Highly Unusual Behavior
# 564     9552        616      0.000           0.00  Highly Unusual Behavior
# 565     9550      18977      0.000           0.00  Highly Unusual Behavior
# 566     9508        199      0.000           0.00  Highly Unusual Behavior
# 567    20665     298151      5.000           0.00  Highly Unusual Behavior
# 568     9594        300      0.000           0.00  Highly Unusual Behavior
# 569    20664      11027      0.000           0.00  Highly Unusual Behavior
# 570    29987       2220      0.000           0.00  Highly Unusual Behavior
# 571    20662      89137      0.000           0.00  Highly Unusual Behavior
# 572    27470     104264      0.000           0.00  Highly Unusual Behavior
# 573    23336       1800      0.000           0.00  Highly Unusual Behavior
# 574    25547      29002      0.000           0.00  Highly Unusual Behavior
# 575     9608       3614      0.000           0.00  Highly Unusual Behavior
# 576     9610      17614      0.000           0.00  Highly Unusual Behavior
# 577     9492       2158      0.000           0.00  Highly Unusual Behavior
# 578    20653      10846      0.000           0.00  Highly Unusual Behavior
# 579     9622      86107      0.000           0.00  Highly Unusual Behavior
# 580     9623       1651      0.000           0.00  Highly Unusual Behavior
# 581     5342        780      0.000           0.00  Highly Unusual Behavior
# 582    25535        390      0.000           0.00  Highly Unusual Behavior
# 583    29975      10904      0.000           0.00  Highly Unusual Behavior
# 584    20645        390      0.000           0.00  Highly Unusual Behavior
# 585     9633      52955      0.000           0.00  Highly Unusual Behavior
# 586    14486      17374      0.000           0.00  Highly Unusual Behavior
# 587     9635       4970      0.000           0.00  Highly Unusual Behavior
# 588       51      37042      0.000           0.00  Highly Unusual Behavior
# 589     9641      14181      0.000           0.00  Highly Unusual Behavior
# 590    20639      30900      0.000           0.00  Highly Unusual Behavior
# 591    14477      16240      0.000           0.00  Highly Unusual Behavior
# 592     9473     225416      0.000           0.00  Highly Unusual Behavior
# 593    25585      27223      0.000           0.00  Highly Unusual Behavior
# 594     9816      47438      0.000           0.00  Highly Unusual Behavior
# 595     9647      23860      0.000           0.00  Highly Unusual Behavior
# 596       59       1587      0.000           0.00  Highly Unusual Behavior
# 597       63      24987      0.000           0.00  Highly Unusual Behavior
# 598     9659        124      0.000           0.00  Highly Unusual Behavior
# 599       65         99      0.000           0.00  Highly Unusual Behavior
# 600       66     152519      0.000           0.00  Highly Unusual Behavior
# 601    20710      54297      0.000           0.00  Highly Unusual Behavior
# 602       70      18565      0.000           0.00  Highly Unusual Behavior
# 603       71        780      0.000           0.00  Highly Unusual Behavior
# 604     9661      27160      0.000           0.00  Highly Unusual Behavior
# 605    25511      81601      0.000           0.00  Highly Unusual Behavior
# 606     9463      49732      0.000           0.00  Highly Unusual Behavior
# 607    29956        380      0.000           0.00  Highly Unusual Behavior
# 608     9672       2400      0.000           0.00  Highly Unusual Behavior
# 609    25590       5748      0.000           0.00  Highly Unusual Behavior
# 610    20615      49926      0.000           0.00  Highly Unusual Behavior
# 611     9452      15641      0.000           0.00  Highly Unusual Behavior
# 612    25596      18486      0.000           0.00  Highly Unusual Behavior
# 613     5339       1650      0.000           0.00  Highly Unusual Behavior
# 614     9494       3570      0.000           0.00  Highly Unusual Behavior
# 615     9446      17007      0.000           0.00  Highly Unusual Behavior
# 616     9444       3084      0.000           0.00  Highly Unusual Behavior
# 617    23316       4918      0.000           0.00  Highly Unusual Behavior
# 618    29951        528      0.000           0.00  Highly Unusual Behavior
# 619     9441        200      0.000           0.00  Highly Unusual Behavior
# 620       90       8583      0.000           0.00  Highly Unusual Behavior
# 621    20722       2400      0.000           0.00  Highly Unusual Behavior
# 622       92       7524      0.000           0.00  Highly Unusual Behavior
# 623     5380     143650      0.000           0.00  Highly Unusual Behavior
# 624     9438      24611      0.000           0.00  Highly Unusual Behavior
# 625    20723     177116      0.000           0.00  Highly Unusual Behavior
# 626     9692         78      0.000           0.00  Highly Unusual Behavior
# 627    25604        162      0.000           0.00  Highly Unusual Behavior
# 628    25505       3700      0.000           0.00  Highly Unusual Behavior
# 629     9697      16501      0.000           0.00  Highly Unusual Behavior
# 630      105      56685      0.000           0.00  Highly Unusual Behavior
# 631      106       5580      0.000           0.00  Highly Unusual Behavior
# 632    29945      75635      0.000           0.00  Highly Unusual Behavior
# 633    23314        232      0.000           0.00  Highly Unusual Behavior
# 634     9701      13759      0.000           0.00  Highly Unusual Behavior
# 635    20731     170146      0.000           0.00  Highly Unusual Behavior
# 636    20585      51086      0.000           0.00  Highly Unusual Behavior
# 637    14536        229      0.000           0.00  Highly Unusual Behavior
# 638      116      18199      0.000           0.00  Highly Unusual Behavior
# ...
# 27188  14284       1714  23604.125        1377.14          Normal Behavior
# 27189  24450        231   3190.000        1380.95          Normal Behavior
# 27190  28795       1133  15666.500        1382.74          Normal Behavior
# 27191  16836       1246  17328.000        1390.69          Normal Behavior
# 27192  29630       1124  15666.500        1393.82          Normal Behavior
# 27193    153        208   2906.000        1397.12          Normal Behavior
# 27194   9744        273   3850.625        1410.49          Normal Behavior
# 27195  10516        779  11000.000        1412.07          Normal Behavior
# 27196   8044        396   5596.000        1413.13          Normal Behavior
# 27197  26211       1108  15666.500        1413.94          Normal Behavior
# 27198  19988        500   7081.000        1416.20          Normal Behavior
# 27199  29855        700   9916.000        1416.57          Normal Behavior
# 27200  14044       1103  15666.500        1420.35          Normal Behavior
# 27201  14819       1099  15666.500        1425.52          Normal Behavior
# 27202   6935        262   3771.000        1439.31          Normal Behavior
# 27203   3868       1638  23604.125        1441.03          Normal Behavior
# 27204   6461       1630  23604.125        1448.11          Normal Behavior
# 27205   2147       1080  15666.500        1450.60          Normal Behavior
# 27206  19052        555   8078.000        1455.50          Normal Behavior
# 27207   7212        263   3850.625        1464.12          Normal Behavior
# 27208  18628       1608  23604.125        1467.92          Normal Behavior
# 27209  12402       1600  23604.125        1475.26          Normal Behavior
# 27210   3906        130   1926.000        1481.54          Normal Behavior
# 27211  11697        188   2791.000        1484.57          Normal Behavior
# 27212  10982        525   7797.000        1485.14          Normal Behavior
# 27213  24216       1576  23604.125        1497.72          Normal Behavior
# 27214  22895        389   5890.000        1514.14          Normal Behavior
# 27215  24285        694  10524.000        1516.43          Normal Behavior
# 27216  29667       1556  23604.125        1516.97          Normal Behavior
# 27217  16876        163   2508.000        1538.65          Normal Behavior
# 27218  18913        269   4166.000        1548.70          Normal Behavior
# 27219  12727        339   5322.000        1569.91          Normal Behavior
# 27220  11210        198   3125.000        1578.28          Normal Behavior
# 27221    277        171   2728.000        1595.32          Normal Behavior
# 27222   7748       1348  21532.000        1597.33          Normal Behavior
# 27223  13403        980  15666.500        1598.62          Normal Behavior
# 27224   7707         85   1377.000        1620.00          Normal Behavior
# 27225   3982         96   1560.000        1625.00          Normal Behavior
# 27226   6399        236   3850.625        1631.62          Normal Behavior
# 27227  18372        956  15666.500        1638.76          Normal Behavior
# 27228   5214        344   5757.000        1673.55          Normal Behavior
# 27229    206        227   3850.625        1696.31          Normal Behavior
# 27230  10294       1391  23604.125        1696.92          Normal Behavior
# 27231  29267       1386  23604.125        1703.04          Normal Behavior
# 27232  27998        325   5581.000        1717.23          Normal Behavior
# 27233  10426        612  10612.000        1733.99          Normal Behavior
# 27234  24117       1358  23604.125        1738.15          Normal Behavior
# 27235   7895        485   8451.875        1742.65          Normal Behavior
# 27236   7689        219   3850.625        1758.28          Normal Behavior
# 27237  20331        187   3327.000        1779.14          Normal Behavior
# 27238  26307        871  15666.500        1798.68          Normal Behavior
# 27239  23849        265   4786.000        1806.04          Normal Behavior
# 27240     40        498   9075.000        1822.29          Normal Behavior
# 27241   4184       1223  22313.000        1824.45          Normal Behavior
# 27242  22665        621  11420.000        1838.97          Normal Behavior
# 27243  17428        845  15666.500        1854.02          Normal Behavior
# 27244  19634       1273  23604.125        1854.21          Normal Behavior
# 27245  24533        229   4261.000        1860.70          Normal Behavior
# 27246   8968       1257  23604.125        1877.81          Normal Behavior
# 27247  21325        829  15666.500        1889.81          Normal Behavior
# 27248  13079        283   5361.000        1894.35          Normal Behavior
# 27249  12435        170   3224.000        1896.47          Normal Behavior
# 27250   3850        390   7412.000        1900.51          Normal Behavior
# 27251  23232        211   4031.000        1910.43          Normal Behavior
# 27252    459        819  15666.500        1912.88          Normal Behavior
# 27253  21305        390   7516.000        1927.18          Normal Behavior
# 27254  19635       1215  23604.125        1942.73          Normal Behavior
# 27255  18569        777  15103.000        1943.76          Normal Behavior
# 27256  17576        193   3760.000        1948.19          Normal Behavior
# 27257   8981        170   3318.000        1951.76          Normal Behavior
# 27258  28791        535  10468.000        1956.64          Normal Behavior
# 27259  19906        290   5692.000        1962.76          Normal Behavior
# 27260  22962        430   8451.875        1965.55          Normal Behavior
# 27261   2273       1195  23604.125        1975.24          Normal Behavior
# 27262  10028        281   5631.000        2003.91          Normal Behavior
# 27263  22954        421   8451.875        2007.57          Normal Behavior
# 27264  21942        191   3850.625        2016.03          Normal Behavior
# 27265  10717       1152  23604.125        2048.97          Normal Behavior
# 27266  27000        186   3842.000        2065.59          Normal Behavior
# 27267   6775        748  15666.500        2094.45          Normal Behavior
# 27268  13026        500  10500.000        2100.00          Normal Behavior
# 27269  16588       1123  23604.125        2101.88          Normal Behavior
# 27270   2557        508  10712.000        2108.66          Normal Behavior
# 27271   1005        456   9664.000        2119.30          Normal Behavior
# 27272  11808        326   6914.000        2120.86          Normal Behavior
# 27273   2401        220   4686.000        2130.00          Normal Behavior
# 27274  22039        396   8451.875        2134.31          Normal Behavior
# 27275  16473        390   8451.875        2167.15          Normal Behavior
# 27276  11327        390   8451.875        2167.15          Normal Behavior
# 27277  14512       1089  23604.125        2167.50          Normal Behavior
# 27278  24105        326   7132.000        2187.73          Normal Behavior
# 27279  26410        280   6192.000        2211.43          Normal Behavior
# 27280  11768        167   3700.000        2215.57          Normal Behavior
# 27281  29091        465  10451.000        2247.53          Normal Behavior
# 27282  17727        228   5241.000        2298.68          Normal Behavior
# 27283  21452        140   3230.000        2307.14          Normal Behavior
# 27284   2962        348   8047.000        2312.36          Normal Behavior
# 27285  14017        197   4568.000        2318.78          Normal Behavior
# 27286   9078        800  18873.000        2359.13          Normal Behavior
# 27287  27042        207   4907.000        2370.53          Normal Behavior
# 27288  22582        660  15666.500        2373.71          Normal Behavior
# 27289   3944        261   6229.000        2386.59          Normal Behavior
# 27290  20709        185   4418.000        2388.11          Normal Behavior
# 27291   2591        586  14076.000        2402.05          Normal Behavior
# 27292  12398        723  17392.000        2405.53          Normal Behavior
# 27293  17554        207   4999.000        2414.98          Normal Behavior
# 27294  15612        648  15666.500        2417.67          Normal Behavior
# 27295   3600        198   4848.000        2448.48          Normal Behavior
# 27296  25811        964  23604.125        2448.56          Normal Behavior
# 27297   6067        280   6859.000        2449.64          Normal Behavior
# 27298  12822        886  21831.000        2464.00          Normal Behavior
# 27299  13260        145   3600.000        2482.76          Normal Behavior
# 27300  27323        880  22311.000        2535.34          Normal Behavior
# 27301  25082        931  23604.125        2535.35          Normal Behavior
# 27302  15630        314   8000.000        2547.77          Normal Behavior
# 27303   1342        267   6817.000        2553.18          Normal Behavior
# 27304   9186        359   9188.000        2559.33          Normal Behavior
# 27305  24218        481  12381.000        2574.01          Normal Behavior
# 27306  12691        252   6546.000        2597.62          Normal Behavior
# 27307   5182        528  13921.000        2636.55          Normal Behavior
# 27308  23863        121   3204.000        2647.93          Normal Behavior
# 27309  27154        346   9182.000        2653.76          Normal Behavior
# 27310  28291        390  10426.000        2673.33          Normal Behavior
# 27311  17194        316   8451.875        2674.64          Normal Behavior
# 27312   9059        316   8451.875        2674.64          Normal Behavior
# 27313  22785        316   8451.875        2674.64          Normal Behavior
# 27314   9439        411  11038.000        2685.64          Normal Behavior
# 27315   1825        254   6840.000        2692.91          Normal Behavior
# 27316  23279        575  15666.500        2724.61          Normal Behavior
# 27317  25526        304   8288.000        2726.32          Normal Behavior
# 27318  29119        570  15666.500        2748.51          Normal Behavior
# 27319    132         95   2622.000        2760.00          Normal Behavior
# 27320   9760         80   2230.000        2787.50          Normal Behavior
# 27321  10951        292   8144.000        2789.04          Normal Behavior
# 27322   5726        449  12611.000        2808.69          Normal Behavior
# 27323  14749        509  14310.000        2811.39          Normal Behavior
# 27324   5037        368  10550.000        2866.85          Normal Behavior
# 27325  20233        390  11223.000        2877.69          Normal Behavior
# 27326  11866        330   9500.000        2878.79          Normal Behavior
# 27327  24017        231   6673.000        2888.74          Normal Behavior
# 27328  18824        542  15666.500        2890.50          Normal Behavior
# 27329  16350        349  10152.000        2908.88          Normal Behavior
# 27330  11447        227   6692.000        2948.02          Normal Behavior
# 27331  11958        500  14883.000        2976.60          Normal Behavior
# 27332   4232        106   3166.000        2986.79          Normal Behavior
# 27333   3803        282   8451.875        2997.12          Normal Behavior
# 27334    372         99   2977.000        3007.07          Normal Behavior
# 27335  14200        461  13966.000        3029.50          Normal Behavior
# 27336  22114        277   8451.875        3051.22          Normal Behavior
# 27337  24267        500  15338.000        3067.60          Normal Behavior
# 27338  21349        275   8451.875        3073.41          Normal Behavior
# 27339  15144        768  23604.125        3073.45          Normal Behavior
# 27340  24077         73   2265.000        3102.74          Normal Behavior
# 27341   8327        454  14213.000        3130.62          Normal Behavior
# 27342  13213        105   3308.000        3150.48          Normal Behavior
# 27343  15356        472  14985.000        3174.79          Normal Behavior
# 27344   8064        218   7022.000        3221.10          Normal Behavior
# 27345  13874        484  15904.000        3285.95          Normal Behavior
# 27346  20563        188   6229.000        3313.30          Normal Behavior
# 27347  29028        194   6479.000        3339.69          Normal Behavior
# 27348  28042        466  15666.500        3361.91          Normal Behavior
# 27349    801        385  13032.000        3384.94          Normal Behavior
# 27350   5297        125   4366.000        3492.80          Normal Behavior
# 27351  22983        270   9483.000        3512.22          Normal Behavior
# 27352   9809        441  15666.500        3552.49          Normal Behavior
# 27353   2505        440  15666.500        3560.57          Normal Behavior
# 27354  14198        655  23537.000        3593.44          Normal Behavior
# 27355  23666         50   1800.000        3600.00          Normal Behavior
# 27356  25692        565  20650.000        3654.87          Normal Behavior
# 27357  13594        301  11063.000        3675.42          Normal Behavior
# 27358  12647        453  16783.000        3704.86          Normal Behavior
# 27359  28957        522  20007.000        3832.76          Normal Behavior
# 27360   2835        400  15666.500        3916.63          Normal Behavior
# 27361  20318        390  15666.500        4017.05          Normal Behavior
# 27362   3385        390  15666.500        4017.05          Normal Behavior
# 27363  27978        364  14662.000        4028.02          Normal Behavior
# 27364   7167        226   9125.000        4037.61          Normal Behavior
# 27365  26508        583  23604.125        4048.73          Normal Behavior
# 27366   7205        577  23604.125        4090.84          Normal Behavior
# 27367  20616        352  14547.000        4132.67          Normal Behavior
# 27368  14940        371  15666.500        4222.78          Normal Behavior
# 27369  23916         90   3850.625        4278.47          Normal Behavior
# 27370  27101        530  23604.125        4453.61          Normal Behavior
# 27371  18840        346  15666.500        4527.89          Normal Behavior
# 27372   9669        367  16652.000        4537.33          Normal Behavior
# 27373  20544        144   6636.000        4608.33          Normal Behavior
# 27374  13827        325  15666.500        4820.46          Normal Behavior
# 27375  15512         75   3707.000        4942.67          Normal Behavior
# 27376   2735        316  15666.500        4957.75          Normal Behavior
# 27377  28053         77   3850.625        5000.81          Normal Behavior
# 27378  20823        305  15666.500        5136.56          Normal Behavior
# 27379  28666         31   2000.000        6451.61          Normal Behavior
# 27380   2245        228  15666.500        6871.27          Normal Behavior
# 27381   8679        326  23604.125        7240.53          Normal Behavior
# 27382  21239         59   4465.000        7567.80          Normal Behavior
# 27383  11421        198  15666.500        7912.37          Normal Behavior
# 27384  28322         86   7066.000        8216.28          Normal Behavior
# 27385  21156        287  23604.125        8224.43          Normal Behavior
# 27386  14083         14   1205.000        8607.14          Normal Behavior
# 27387  26215        268  23604.125        8807.51          Normal Behavior
# 27388  22443        260  23604.125        9078.51          Normal Behavior
# 27389   2241        202  23604.125       11685.21          Normal Behavior
# 27390  21952        106  15666.500       14779.72          Normal Behavior
# 27391  26867         73  10952.000       15002.74          Normal Behavior
# 27392   8331          8   1274.000       15925.00          Normal Behavior
# 27393    974         50   8589.000       17178.00          Normal Behavior
# 27394  20999         80  15666.500       19583.13          Normal Behavior
# 27395  15362          9   1960.000       21777.78          Normal Behavior
# 27396  17677         47  23604.125       50221.54          Normal Behavior
# 27397  25520         38  23604.125       62116.12          Normal Behavior
# 27398  25115          1   1001.000      100100.00          Normal Behavior
# 27399  13971          3   3850.625      128354.17          Normal Behavior
# 27400   3413          3  13333.000      444433.33          Normal Behavior

# %%
# Grouping the payment behavior

query = """
SELECT
    payment_behavior,
    COUNT(*) AS customer_count
FROM (
    SELECT
        id,
        bill_amt1,
        pay_amt1,
        ROUND(CAST((pay_amt1 / NULLIF(bill_amt1, 0)) * 100 AS NUMERIC), 2) AS payment_ratio,
        CASE
            WHEN(pay_amt1 / NULLIF(bill_amt1, 0)) < 0.05 THEN 'Highly Unusual Behavior'
            WHEN(pay_amt1 / NULLIF(bill_amt1, 0)) < 0.10 THEN 'Unusual Behavior'
            ELSE 'Normal Behavior'
        END AS payment_behavior
    FROM credit_data
    WHERE bill_amt1 > 0
) AS subquery
GROUP BY payment_behavior
ORDER BY customer_count DESC;
"""
payment_behavior_group = pd.read_sql(query, engine)
payment_behavior_group
# Out:
#           payment_behavior  customer_count
# 0  Highly Unusual Behavior           11555
# 1          Normal Behavior           10381
# 2         Unusual Behavior            5465

# %%
# Checking for the default rates for each payment behavior: by counting the number of customers in each group, counting the number if defaulters, calculating the default rate

query = """
SELECT
    payment_behavior,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS default_rate
FROM (
    SELECT
        id,
        bill_amt1,
        pay_amt1,
        default_payment_next_month,
        ROUND(CAST((pay_amt1 / NULLIF(bill_amt1, 0)) * 100 AS NUMERIC), 2) AS payment_ratio,
        CASE
            WHEN (pay_amt1 / NULLIF(bill_amt1, 0)) < 0.05 THEN 'Highly Unusual Behavior'
            WHEN (pay_amt1 / NULLIF(bill_amt1, 0)) < 0.10 THEN 'Unusual Behavior'
            ELSE 'Normal Behavior'
        END AS payment_behavior
    FROM credit_data
    WHERE bill_amt1 > 0
) AS subquery
GROUP BY payment_behavior
ORDER BY default_rate DESC;
"""
payment_default_rates = pd.read_sql(query, engine)
payment_default_rates
# Out:
#           payment_behavior  total_customers  defaulters  default_rate
# 0  Highly Unusual Behavior            11555        2954         25.56
# 1         Unusual Behavior             5465        1188         21.74
# 2          Normal Behavior            10381        1851         17.83

# %% [markdown]
# Observations:
# - Some customers with 'Highly Unusual Behavior' might be paying way more than their actual bill
# - Some customers with 'Normal Behavior' might have small bills but large payment
#
# Action:
# - Combining Unusual Repayment Behavior with Credit Limit Categories
# - By grouping both repayment behavior & credit limit, to see if default trends differ across credit levels

# %%
# Classifying repayment behavior within each credit limit group

query = """
SELECT
    credit_limit_category,
    payment_behavior,
    COUNT(*) AS total_customers,
    SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) AS defaulters,
    ROUND(100.0 * SUM(CASE WHEN default_payment_next_month = 1 THEN 1 ELSE 0 END) / COUNT(*), 2) AS default_rate
FROM(
    SELECT
        id,
        bill_amt1,
        pay_amt1,
        default_payment_next_month,

        CASE
            WHEN limit_bal BETWEEN 0 AND 50000 THEN 'Low Credit Limit'
            WHEN limit_bal BETWEEN 50001 AND 140000 THEN 'Medium Credit Limit'
            WHEN limit_bal BETWEEN 140001 AND 240000 THEN 'High Credit Limit'
            ELSE 'Very High Credit Limit'
        END AS credit_limit_category,

        CASE
            WHEN pay_amt1 < 100 OR (pay_amt1 / NULLIF(bill_amt1, 0)) < 0.50 THEN 'Highly Unusual Behavior'
            WHEN pay_amt1 BETWEEN 100 AND 500 OR (pay_amt1 / NULLIF(bill_amt1, 0)) < 0.10 THEN 'Unusual Behavior'
            ELSE 'Normal Behavior'
        END AS payment_behavior
    FROM credit_data
    WHERE bill_amt1 > 0
) AS subquery
GROUP BY credit_limit_category, payment_behavior
ORDER BY credit_limit_category, default_rate DESC;
"""
unusual_repayment_credit = pd.read_sql(query, engine)
unusual_repayment_credit
# Out:
#      credit_limit_category         payment_behavior  total_customers  \
# 0        High Credit Limit         Unusual Behavior              210
# 1        High Credit Limit  Highly Unusual Behavior             4934
# 2        High Credit Limit          Normal Behavior             1549
# 3         Low Credit Limit  Highly Unusual Behavior             6776
# 4         Low Credit Limit         Unusual Behavior               85
# 5         Low Credit Limit          Normal Behavior              497
# 6      Medium Credit Limit         Unusual Behavior              144
# 7      Medium Credit Limit  Highly Unusual Behavior             6270
# 8      Medium Credit Limit          Normal Behavior              732
# 9   Very High Credit Limit         Unusual Behavior              139
# 10  Very High Credit Limit  Highly Unusual Behavior             4344
# 11  Very High Credit Limit          Normal Behavior             1721
#
#     defaulters  default_rate
# 0           44         20.95
# 1          847         17.17
# 2          218         14.07
# 3         2209         32.60
# 4           24         28.24
# 5          131         26.36
# 6           47         32.64
# 7         1589         25.34
# 8          131         17.90
# 9           24         17.27
# 10         575         13.24
# 11         154          8.95

# %% [markdown]
# Observations:
# - Medium Credit Limit + Unusual Behavior = 32.64
# - Low Credit Limit + Highly Unusual Behavior = 32.60
# - Low Credit Limit + Unusual Behavior = 28.24
# - Low Credit Limit + Normal Behavior = 26.36
#
# - Customers with Medium + Low credit limits with Unusual + Highly Unusual Repayment Behavior have the highest chance of defaulting
# - Customers with Low credit limits might be struggling with replayments or engaging in risky behavior

# %%
unusual_repayment_credit.to_csv("../data/unusual_repayment_behavior.csv", index=False)

# %%
query = """
SELECT 
    id,
    ROUND(CAST(AVG(NULLIF(pay_amt1, 0) / NULLIF(bill_amt1, 0)) AS NUMERIC), 2) AS avg_payment_ratio,
    SUM(bill_amt1 + bill_amt2 + bill_amt3 + bill_amt4 + bill_amt5 + bill_amt6) AS total_bill_amt,
    SUM(pay_amt1 + pay_amt2 + pay_amt3 + pay_amt4 + pay_amt5 + pay_amt6) AS total_pay_amt,
    SUM(default_payment_next_month) AS default_history,
    ROUND(CAST(SUM(bill_amt1 + bill_amt2 + bill_amt3 + bill_amt4 + bill_amt5 + bill_amt6) / NULLIF(AVG(limit_bal), 0) AS NUMERIC), 2) AS credit_utilization
FROM credit_data
GROUP BY id;
"""
customer_payment_stats = pd.read_sql(query, engine)

# %%
customer_payment_stats.to_csv("../data/customer_payment_stats.csv", index=False)
